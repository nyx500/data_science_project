# %% [markdown]
# # BSc Computer Science CM3005 (Data Science) Midterm Coursework on Linear Regression

# %% [markdown]
# ## Task 1: Domain-Specific Area and Objectives of the Project
#
# > "Weather has had a greater effect on sales than economic numbers, we’ve known that forever."
# > </br>
# > [Andy Street, John Lewis Managing Director, 2014](https://www.preventionweb.net/news/met-office-review-uks-record-breaking-summer-2022)*
#
# ### (a) Introducing the Domain: *Quantifying the Influence of Weather on Retail Sales in the UK from 1988 to 2023*
#
# This is a question aimed at anyone living in typically cool and rainy climate, like the UK:
# </br></br>
# *Have you ever experienced the frustration and annoyance of going clothes shopping during a particularly blustery and wet February or March and finding that all the fashion collections are full of spring-themed floral, summery dresses and floaty cardigans, when all you want is snuggly quilted parka or a wooly jumper?*
# </br></br>
# It's hard to believe that spring could be just around the corner when it's sleeting outside - which continue for a couple more weeks if not months! As a Pole, my personal experience of shopping in "springtime" in Poland has involved seeing Spanish-owned international apparel retail companies such as Zara and Bershka selling their springtime collections in March in a country which frequently sees snow at the beginning of May. Personally, I have always wondered how clothing companies have managed to make money during these transition periods!
# </br>
# </br>
# As such, the purpose of this data analysis is to explore and quantify the impact of the weather on retail sales in the UK by implementing several statistical techniques as well as a linear regression model (in Python).
# </br>
# </br>
# Although it has been widely acknowledged in both economic research and the media that the weather has an important effect on consumer spending patterns and daily business activity, so far it has proven very difficult to determine precisely what the nature of this relationship is [(WeatherAds.io)](https://www.weatherads.io/blog/the-impact-of-weather-on-retail-sector-in-the-uk#:~:text=In%20the%20UK%20%E2%80%93%20a%20country,a%201%25%20fluctuation%20in%20sales).
# </br>
# </br>
# For instance, this *Guardian* article suggested that wet and cold weather during a specific month led to an unexpected fall in retail sales
# [(*The Guardian: Wet weather dampens retail sales in Great Britain*)](https://www.weatherads.io/blog/the-impact-of-weather-on-retail-sector-in-the-uk#:~:text=In%20the%20UK%20%E2%80%93%20a%20country,a%201%25%20fluctuation%20in%20sales),
# while this one on *Euronews* blamed the **above-average** temperatures for a decline in consumer spending  [(*Euronews: Cost of living and hot weather cause retail sales to fall in UK*)](https://www.euronews.com/business/2023/10/20/cost-of-living-and-hot-weather-cause-retail-sales-to-fall-in-uk). One could argue that warm weather would make consumers less likely to go shopping as they would engage more in sports and other outdoor activities, while on the other hand, one article posits that </br>
# </br>
# > "It has been proven that after exposure to sunlight consumers are more willing to self-reward (i.e. make purchases), and are also willing to pay more for goods and services. It has also been shown that when consumers are in a warm environment, their purchase intent increases, and they judge the value of certain items higher. In addition the same study found that warmth leads consumers to be more easily swayed by marketing messages."
# </br>
# [(WeatherAds.io)](https://www.weatherads.io/blog/the-impact-of-weather-on-retail-sector-in-the-uk#:~:text=In%20the%20UK%20%E2%80%93%20a%20country,a%201%25%20fluctuation%20in%20sales)
# </br>
# </br>
#
# Despite its complexity, it is undoubtable that examining the nature of this relationship more closely be of value for a range of different stakeholders, including retail company managers, shareholders, governmental institutions and potential investors. As [Badorf and Hoberg](https://www.researchgate.net/publication/335173325_The_impact_of_daily_weather_on_retail_sales_An_empirical_study_in_brick-and-mortar_stores#:~:text=The%20effect%20on%20daily%20sales,not%20consider%20non%2Dlinear%20effects) outline in their 2020 study on the impact of daily weather on sales in 673 German retail stores, weather "has an immediate effect on daily businesses and sales", and precipitation and temperature "significantly influence people's behavior", although it is "unclear how".
#
# What makes the investigation of this relationship particularly topical and timely is that in recent years, the UK, together with other areas of north-west Europe, has experienced increasingly warm and dry summer temperatures due to the effects of climate change, with temperatures of over 40C being reached during summer 2022 in the UK for the first time [(*UNDRR PreventionWeb*)](https://www.preventionweb.net/news/met-office-review-uks-record-breaking-summer-2022). Establishing the effect of hot/dry weather in the summer on retail sales is especially important in this context where this trend is expect to continue due to global warming. For example, shop owners might decide to invest in air-conditioning or different building materials if it the data suggests that temperatures over a certain value discourage people from browsing in their stores.
#
# ### (b) Project Objectives
# - To collect, pre-process, and statistically summarize datasets containing historic UK retail prices and weather data.
# - To use visualization libraries in Python to get an overview of the important trends, patterns and relationships within the data.
# - To determine the effect of weather on UK retail sales using statistical analysis and linear regression.
# - To determine which weather parameters (e.g temperature, wind, precipitation) have the greatest effect on sales.
# - To determine if a polynomial regression model should be used in case the relationship is not linear.
#
# ### (c) Proposed Impact of Study
# Retail sales are often considered as a "barometer" for the overall health of an economy - for instance, consumer spending accounts for 60% of the UK's GDP per capita [(*Admirals.com*)](https://admirals.com/financial-events/why-retail-sales-important), and the sector accounts for about 3 million jobs. Therefore, sales figures inform economists about consumer demand for finished products, whether the economy is expanding or contracting, and likely trends in the unemployment rate. Importantly, they are considered to be a **reliable** economic indicator of growth [(*Finance.Yahoo.com*)](https://finance.yahoo.com/news/retail-sales-mean-economy-110029982.html), as well as having a profound impact on foreign investment [(*DailyFx.com*)](https://www.dailyfx.com/education/macro-fundamentals/what-are-retail-sales-and-why-is-it-important-to-traders-a-guide.html). Consequently, an examination of how weather impacts sales can potentially be of use to the following stakeholders:
#
# ### (d) Key Stakeholders
# - Governmental institutions have a vested interest in trends in retail sales in order to gauge how well businesses are doing and to assess consumers' levels of disposable income [(*Dailyfx.com*)](https://www.dailyfx.com/education/macro-fundamentals/what-are-retail-sales-and-why-is-it-important-to-traders-a-guide.html)
# - Retail companies can use these kinds of investigations for the basis of their data-driven decision making. To provide just one example, being able to sync advertisements to match appropriate weather conditions and decreasing ad-spend during periods of less-favourable weather can lead to the decrease of costs for the company [(*WeatherAds.io*)](https://www.weatherads.io/blog/the-impact-of-weather-on-retail-sector-in-the-uk#:~:text=In%20the%20UK%20%E2%80%93%20a%20country,a%201%25%20fluctuation%20in%20sales)
# - Central banking and monetary regulation institutions adjust interest rates based on consumer demand and sales to control inflation, thus building models to predict trends in spending can lead to a better-informed adaptation of rates [(*Admirals.com*)](https://admirals.com/financial-events/why-retail-sales-important).
# - Shareholders, traders and potential investors in retail companies are interested in patterns in sales because retail sales exhibit a positive correlation with stock prices [(*Dailyfx.com*)](https://www.dailyfx.com/education/macro-fundamentals/what-are-retail-sales-and-why-is-it-important-to-traders-a-guide.html)
# - Bondholders are negatively affected by an increase in retail sales, as when inflation rises, bond prices drop [(*Finance.Yahoo.com*)](https://finance.yahoo.com/news/retail-sales-mean-economy-110029982.html)
# - Everyday consumers and small businesses can be benefitted by knowing how demand fluctuates based on weather can be of interest in relation of when to make purchases [(*WeatherAds.io*)](https://www.weatherads.io/blog/the-impact-of-weather-on-retail-sector-in-the-uk#:~:text=In%20the%20UK%20%E2%80%93%20a%20country,a%201%25%20fluctuation%20in%20sales)
#
# ### (e) Possible Limitations and Challenges of this Project
# - **Adjusting retail sales to account for inflation**: ensure that price indices are used to track changes in retail prices/inflation so that changes in spending and sales can be assessed in **real terms** [(*Finance-Monthly.com*)](https://www.finance-monthly.com/2023/01/what-is-retail-sales-why-is-it-important/)
# - **Linear or polynomial model?**: Some academic research has suggested that the relationship between weather and sales is probably non-linear. This suggests that a possible solution would be a model which uses a higher-order polynomial, and thus the model should be adjusted accordingly. However, finding the correct degree of complexity can be challenging [(*Badorf and Hoberg, 2020*)](https://www.researchgate.net/publication/335173325_The_impact_of_daily_weather_on_retail_sales_An_empirical_study_in_brick-and-mortar_stores#:~:text=The%20effect%20on%20daily%20sales,not%20consider%20non%2Dlinear%20effects).
# - **Which parameters/features are important?**: "Weather" that might have an impact on sales is not constricted to just temperature, but also involves parameters such as wind, precipitation and humidity[(*Rose and Dolega, 2021*)](https://www.researchgate.net/publication/354129194_It's_the_Weather_Quantifying_the_Impact_of_Weather_on_Retail_Sales). As such, it can be difficult to select which features have the greatest influence on the outputs (sales figures). Therefore, using domain expertise to determine which parameters have been found the most significant could be a potential solution here.
# - **Which retail sectors are more influenced by the weather?**: Retail sales in certain sectors (e.g. apparel/clothing) may be more influenced by weather fluctuations than other sectors such as electronics, therefore it might be useful to examine the impact of weather on the different sectors as well as generallyenerally
# - **Difficulty of finding historic UK wind data online**: I have faced significant challenges in finding historic wind data for the same dates as the rest of the data for the UK, as this data is not available for free on the MetOffice and is only available if you pay for this service. Wind is an important parameter for investigating how weather affects consumer behaviour, and not having access to data for this parameter it is a great limitation on this study.

# %% [markdown]
# ## Task 2: Dataset Selection
#
# **Sources of data**:
# - Retail Sales Index Figures for the UK: [Office for National Statistics: Retail Sales Index (RSI) QMI](https://www.ons.gov.uk/businessindustryandtrade/retailindustry/methodologies/retailsalesindexrsiqmi)
# - Historic weather data (monthly aggregations for the following parameters - max temp, min temp, mean temp, sunshine, rainfall, rain days >= 1.0mm, days of air frost): [MetOffice: UK and regional series](https://www.metoffice.gov.uk/research/climate/maps-and-data/uk-and-regional-series)
#
# When selecting datasets to analyze the effect of weather on retail sales, there are several issues which must be considered:
#
# 1. **Selecting the <u>time granularity</u> of the sales and weather data**</br>
# - The first question to ask is whether it is better to select data about weather and sales which have data points representing aggregate values daily, weekly, monthly, quarterly or annually. Determining the time granularity of the data depends to a large extent on the research questions we are trying to answer and the kinds of data available. Different granularities come with different advantages and disadvantages which will be touched on briefly here.<br>
# - The advantages of using smaller granularities such as weekly or even daily data are that this enables us to analyze the impact of shorter-term weather fluctuations on sales volumes. It allows capturing rapid shifts in consumer behaviour and volatiliy in demand [(*CashFlowInventory.com Blog*)](https://cashflowinventory.com/blog/monthly-vs-weekly-inventory-forecasting/). For instance, it is possible to account for changes in consumer behaviour during a few exceptionally rainy or stormy days in the middle of summer.
# - Nonetheless, there are important disadvantages of using weekly data over monthly or quarterly data that must be taken into account. The most pertinent issue is that the Office of National Statistics and other sources of retail sales data do not usually provide monthly values for long time periods (over decades), and thus it is difficult to find weekly data. In this study, the focus of the research questions is largely on how increasingly hot summers (due to global warming) might have impacted sales figures, therefore it is important that the time periods spans at least a couple of decades. Furthermore, weekly values can lead to a large volume of data which significantly increases the time taken to train and validate the models. Another advantage of using monthly over weekly data is that these figures smooth out some of the noise in the data, thus making it easier to identify patterns due to decreased volatility [(*CashFlowInventory.com Blog*)](https://cashflowinventory.com/blog/monthly-vs-weekly-inventory-forecasting/).
# - Using annual data might not be the optimal granularity for this project, as this would mean that the data would have a significant lack of detail about how sales patterns change throughout the year based on the seasonal temperatures.
# <br></br> Bearing this in mind, in this project monthly data will be used for the initial research to try to identify key trends and patterns. However, if an overall relationship can be established as a foundation, it might be a good idea to extend the research to weekly data in the future, provided that public and open datasets for these sales figures can be found.
#
# 2. **Seasonally or Non-Seasonally Adjusted Sales Figures?**
# The ONS offers retail sales figures that have been seasonally-adjusted to account for events such as Christmas or Bank Holidays, where retail sales are expected to be affected by such events. When selecting which dataset to use, it first had to be decided whether to use seasonally-adjusted or non-seasonally-adjusted data. Seasonally-adjusted data was chosen as preferable in this context to non-adjusted data for the reason that including increased sales figures before Christmas or Easter would introduce another complicating factor which would make it more difficult to discern the relationship between weather and sales figures. This is how the seasonal-adjustment process is defined on the ONS website:
# > "Seasonally adjusted estimates are derived by estimating and removing calendar effects (for example, Easter moving between March and April) and seasonal effects (for example, increased spending in December as a result of Christmas) from the non-seasonally adjusted estimates. Seasonal adjustment is performed each month and reviewed each year using the standard, widely used software, X-13-ARIMA." </br>
# > [Office for National Statistics](https://www.ons.gov.uk/businessindustryandtrade/retailindustry/methodologies/retailsalesindexrsiqmi)
#
#
# 3. **Selecting the Time Range: 1988 to 2023**</br>
# The ONS's datasets on retail sales span this period of time, which is a relatively long period to analyze this relationship over. The advantage of using a long time period here is that it makes it possible to discern how inflation-adjusted retail sales have been affected by the increasing temperatures of the last few decades. For instance, focusing only on the past 5 or 10 years with weekly-granularity would make it difficult to identify the effect of this. A longer time period minimizes the impact of short-term fluctuations and can hopefully pick up on more general trends.
#
# 4. **Table Selection from the ONS RSI Dataset: Volume or Value?**
# - The [ONS Retail Sales Index](https://www.ons.gov.uk/businessindustryandtrade/retailindustry/datasets/retailsalesindexreferencetables) dataset will be used here. This is a complex spreadsheet with many tables and pages, displaying different metrics and units for measuring changes in volume and value of sales. Table 1M shows the "chained **volume** of retail sales (seasonally adjusted)" as an index with the base year set to 2019 for which the index is 100. As such, a value of 110 for a certain month means that the sales for that month were 10% higher than the average sales in the base year, and 70 means that the sales were 30% lower than the average for the base year.
# - The CPSA Retail Sales Index tables contain the retail sales **value** (taking into account prices as well as amount of sales) as a percentage change for that month on either the same month a year earlier, 3 months on the same period a year earlier, percentage change on the previous month, and percentage change 3 months on the previous 3 months.
# </br>
# - The KPSA tables show the sales **volume** or amount using the Index2019=100 index, as well as percentage changes similar to the CPSA tables described above but for volume rather than value.
# - The first question here is whether the data used in this analysis should account for the volume or the value of monthly retail sales. As the focus here is the economic impact on businesses and how they can maximize profits, value will be chosen rather than volume, especially as the ONS makes it clear that these prices have been adjusted to **account for inflation** across the different sectors:
# > "To remove the direct effects of prices changes, value data are deflated to produce RSI volume measures. A separate price deflator is used for each RSI industry at four-digit SIC."
# > [ONS: Deflation](https://www.ons.gov.uk/businessindustryandtrade/retailindustry/methodologies/retailsalesindexrsiqmi)
#
# - The second question is whether to use the **2019:100** index for the total sales value or to use **percentage changes** instead. The index is better-suited for exploring long-term patterns, while percentage change may be better suited for exploring short-term dynamics. It is difficult to decide at this stage prior to any analysis which metric would be more useful, therefore in the final dataset we will construct for the regression, it might be helpful to start with the index but to later look at the percentage change on the same month a year earlier and then the percentage change on the previous month to examine the data at a greater level of detail after getting a grasp on longer-term trends first.
# - As a result, from the ONS RSI spreadsheets, the tables which will be used and eventually combined (with pandas) into a dataset will be **Tables 2 M - VALUE OF RETAIL SALES AT CURRENT PRICES SEASONALLY ADJUSTED, Index numbers of sales per week and percentage increase on a year earlier, SIC 2007**.
#
# 6. **Value of Retail Sales Dataset Shape and Size** </br>
# The 2M worksheet in the ONS's spreadsheet consists of 2 vertically-stacked tables. The first table displays the value of retail sales as an index using the 2019:100 scale discussed above and consists of monthly entries from January 1988 to October 2023, thus consisting of 429 rows/entries. There are 33 columns here, each one representing a sector of the retail industry, including columns for all retailing and all retailing excluding automotive fuel (it is often a good idea to exclude fuel sales from the sales value as the fuel market is particularly volatile and can obscure general trends in consumer spending):
# ![image.png](attachment:349afc39-5d89-4cda-94f9-9526ebdc865b.png)
# *Sheet 2M of the ONS RSI Dataset: format of first table*
# The table below shows the percentage change on the same month a year earlier for the same sectors:
# ![image.png](attachment:279560c0-6f5a-42a4-acdb-b39f7c4fd592.png)
# *Sheet 2M of the ONS RSI Dataset: format of second table*
#  Stacking these tables on top of each other vertically would result in duplicate entries for a specific month (e.g. a row for March 1995 containing sales values as an index, and then another row containing sales values as a percentage change on the previous year also for March 1995 would result in rows would violate 1NF because each row would not have a unique identifier). Therefore, considerable work has to be done when pre-processing and combining these two tables to normalize them, and to stack percentage changes as columns for each sector horizontally rather than joining the two tables vertically. It is also necessary to combine this dataset with the weather data for each month downloaded from the MetOffice.
#
# 8. **MetOffice Weather Datasets Shape and Size** </br>
# For each parameter/input which will be used here (e.g. month max and min temp, nr of days where rainfall was over 1mm inclusive etc.), the MetOffice has a separate table where the rows range from the year 1884 to 2023. Then, there is one column containing the required parameter/statistic for each month, per season/quarter, and per year. These tables must be combined and re-arranged using pandas so that each row represents a month rather than a year and for the columns to contain the input parameters - such as rainfall, min and max temperature etc. Both datasets contain missing values and this will be handling in the next steps before statistical analysis and regression is done.
# ![image.png](attachment:04b49707-8d12-4760-9d76-06ccefb00539.png)
# *MetOffice Monthly, seasonal and annual number of days in the month with air frost (minimum temperature below zero) for UK: format of table*
# </br>
# </br>
# Following pre-processing, the final table should contain a row per each month, and then contain columns for:
# - the indexed sales value for the different retail sectors
# - the percentage-change-compared-to-last-year for the same month for those retail sectors
# - columns for max temp, min temp, mean temp, sunshine, rainfall, rain days >= 1.0 mm for the month and days of air frost.
